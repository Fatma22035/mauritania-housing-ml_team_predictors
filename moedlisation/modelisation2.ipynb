# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import cross_validate, KFold
from sklearn.linear_model import LinearRegression, Ridge, Lasso
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import xgboost as xgb
import joblib
import matplotlib.pyplot as plt
import seaborn as sns

# %%
train = pd.read_csv('../data/train.csv')
test = pd.read_csv('../data/test.csv')

print("Train shape:", train.shape)
print("Test shape:", test.shape)
print("\nTrain columns:", train.columns.tolist())
print("\nTest columns:", test.columns.tolist())
# Out:
# Train shape: (1153, 36)
# Test shape: (289, 33)
#
# Train columns: ['id', 'titre', 'prix', 'surface_m2', 'nb_chambres', 'nb_salons', 'nb_sdb', 'quartier', 'description', 'caracteristiques', 'source', 'date_publication', 'quartier_encoded', 'log_prix', 'latitude', 'longitude', 'adresse_osm', 'dist_centre_ville_km', 'dist_aeroport_km', 'dist_plage_km', 'nb_ecoles_1km', 'nb_mosquees_1km', 'nb_commerce_1km', 'nb_hopitaux_1km', 'nb_total_pois_1km', 'prix_m2', 'nb_pieces_total', 'type_bien', 'has_garage', 'has_jardin', 'has_piscine', 'has_balcon', 'has_meuble', 'has_titre_foncier', 'est_neuf', 'age_annonce']
#
# Test columns: ['id', 'titre', 'surface_m2', 'nb_chambres', 'nb_salons', 'nb_sdb', 'quartier', 'description', 'caracteristiques', 'source', 'date_publication', 'quartier_encoded', 'latitude', 'longitude', 'adresse_osm', 'dist_centre_ville_km', 'dist_aeroport_km', 'dist_plage_km', 'nb_ecoles_1km', 'nb_mosquees_1km', 'nb_commerce_1km', 'nb_hopitaux_1km', 'nb_total_pois_1km', 'nb_pieces_total', 'type_bien', 'has_garage', 'has_jardin', 'has_piscine', 'has_balcon', 'has_meuble', 'has_titre_foncier', 'est_neuf', 'age_annonce']

# %%
print("\n--- Train info ---")
train.info()
print("\n--- Test info ---")
test.info()
print("\nMissing values in train:")
print(train.isnull().sum())
print("\nMissing values in test:")
print(test.isnull().sum())
# Out:
# --- Train info ---
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1153 entries, 0 to 1152
# Data columns (total 36 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    1153 non-null   int64
#  1   titre                 1153 non-null   object
#  2   prix                  1153 non-null   float64
#  3   surface_m2            1153 non-null   float64
#  4   nb_chambres           1153 non-null   float64
#  5   nb_salons             1153 non-null   float64
#  6   nb_sdb                1153 non-null   float64
#  7   quartier              1153 non-null   object
#  8   description           1153 non-null   object
#  9   caracteristiques      996 non-null    object
#  10  source                1153 non-null   object
#  11  date_publication      1153 non-null   object
#  12  quartier_encoded      1153 non-null   float64
#  13  log_prix              1153 non-null   float64
#  14  latitude              1153 non-null   float64
#  15  longitude             1153 non-null   float64
#  16  adresse_osm           1153 non-null   object
#  17  dist_centre_ville_km  1153 non-null   float64
#  18  dist_aeroport_km      1153 non-null   float64
#  19  dist_plage_km         1153 non-null   float64
#  20  nb_ecoles_1km         1153 non-null   int64
#  21  nb_mosquees_1km       1153 non-null   int64
#  22  nb_commerce_1km       1153 non-null   int64
#  23  nb_hopitaux_1km       1153 non-null   int64
#  24  nb_total_pois_1km     1153 non-null   int64
#  25  prix_m2               1153 non-null   float64
#  26  nb_pieces_total       1153 non-null   int64
#  27  type_bien             1153 non-null   object
#  28  has_garage            1153 non-null   int64
#  29  has_jardin            1153 non-null   int64
#  30  has_piscine           1153 non-null   int64
#  31  has_balcon            1153 non-null   int64
#  32  has_meuble            1153 non-null   int64
#  33  has_titre_foncier     1153 non-null   int64
#  34  est_neuf              1153 non-null   int64
#  35  age_annonce           1153 non-null   int64
# dtypes: float64(13), int64(15), object(8)
# memory usage: 324.4+ KB
#
# --- Test info ---
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 289 entries, 0 to 288
# Data columns (total 33 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    289 non-null    int64
#  1   titre                 289 non-null    object
#  2   surface_m2            289 non-null    float64
#  3   nb_chambres           289 non-null    float64
#  4   nb_salons             289 non-null    float64
#  5   nb_sdb                289 non-null    float64
#  6   quartier              289 non-null    object
#  7   description           289 non-null    object
#  8   caracteristiques      250 non-null    object
#  9   source                289 non-null    object
#  10  date_publication      289 non-null    object
#  11  quartier_encoded      289 non-null    float64
#  12  latitude              289 non-null    float64
#  13  longitude             289 non-null    float64
#  14  adresse_osm           289 non-null    object
#  15  dist_centre_ville_km  289 non-null    float64
#  16  dist_aeroport_km      289 non-null    float64
#  17  dist_plage_km         289 non-null    float64
#  18  nb_ecoles_1km         289 non-null    int64
#  19  nb_mosquees_1km       289 non-null    int64
#  20  nb_commerce_1km       289 non-null    int64
#  21  nb_hopitaux_1km       289 non-null    int64
#  22  nb_total_pois_1km     289 non-null    int64
#  23  nb_pieces_total       289 non-null    int64
#  24  type_bien             289 non-null    object
#  25  has_garage            289 non-null    int64
#  26  has_jardin            289 non-null    int64
#  27  has_piscine           289 non-null    int64
#  28  has_balcon            289 non-null    int64
#  29  has_meuble            289 non-null    int64
#  30  has_titre_foncier     289 non-null    int64
#  31  est_neuf              289 non-null    int64
#  32  age_annonce           289 non-null    int64
# dtypes: float64(10), int64(15), object(8)
# memory usage: 74.6+ KB
#
# Missing values in train:
# id                        0
# titre                     0
# prix                      0
# surface_m2                0
# nb_chambres               0
# nb_salons                 0
# nb_sdb                    0
# quartier                  0
# description               0
# caracteristiques        157
# source                    0
# date_publication          0
# quartier_encoded          0
# log_prix                  0
# latitude                  0
# longitude                 0
# adresse_osm               0
# dist_centre_ville_km      0
# dist_aeroport_km          0
# dist_plage_km             0
# nb_ecoles_1km             0
# nb_mosquees_1km           0
# nb_commerce_1km           0
# nb_hopitaux_1km           0
# nb_total_pois_1km         0
# prix_m2                   0
# nb_pieces_total           0
# type_bien                 0
# has_garage                0
# has_jardin                0
# has_piscine               0
# has_balcon                0
# has_meuble                0
# has_titre_foncier         0
# est_neuf                  0
# age_annonce               0
# dtype: int64
#
# Missing values in test:
# id                       0
# titre                    0
# surface_m2               0
# nb_chambres              0
# nb_salons                0
# nb_sdb                   0
# quartier                 0
# description              0
# caracteristiques        39
# source                   0
# date_publication         0
# quartier_encoded         0
# latitude                 0
# longitude                0
# adresse_osm              0
# dist_centre_ville_km     0
# dist_aeroport_km         0
# dist_plage_km            0
# nb_ecoles_1km            0
# nb_mosquees_1km          0
# nb_commerce_1km          0
# nb_hopitaux_1km          0
# nb_total_pois_1km        0
# nb_pieces_total          0
# type_bien                0
# has_garage               0
# has_jardin               0
# has_piscine              0
# has_balcon               0
# has_meuble               0
# has_titre_foncier        0
# est_neuf                 0
# age_annonce              0
# dtype: int64

# %%
sns.histplot(train['prix'], bins=50, kde=True)
plt.title('Distribution des prix (train)')
plt.show()

# Log-transform pour mieux visualiser
train['log_prix'] = np.log1p(train['prix'])
sns.histplot(train['log_prix'], bins=50, kde=True)
plt.title('Distribution du log(prix) (train)')
plt.show()

# %% [markdown]
# Étape 2.1 : Inspection rapide
# ---------------

# %%
# Afficher les premières lignes pour se familiariser
print("Train - aperçu :")
print(train.head())
print("\nTest - aperçu :")
print(test.head())
# Vérifier les dimensions
print(f"\nTrain shape: {train.shape}")
print(f"Test shape: {test.shape}")
# Vérifier les types de données et les valeurs manquantes
print("\n--- Train info ---")
train.info()
print("\n--- Test info ---")
test.info()
# Compter les valeurs manquantes par colonne
print("\nValeurs manquantes dans train :")
print(train.isnull().sum())
print("\nValeurs manquantes dans test :")
print(test.isnull().sum())
# Out:
# Train - aperçu :
#      id                                              titre       prix  \
# 0  1076                    منزل احذ اللنكات حمام الياسمين   1800000.0
# 1   875  فرصة دار مكونه من طابقين ارضي و واحد فوقوني كا...  1800000.0
# 2   453                               دار فتيارت فاتح فبرك   900000.0
# 3   987       دار للبيـــــــــــــــــــــع أفي عين الطلح  1600000.0
# 4   252                                        ملح سكتير 2   800000.0
#
#    surface_m2  nb_chambres  nb_salons  nb_sdb       quartier  \
# 0       150.0          3.0        2.0     2.0         arafat
# 1       300.0          6.0        3.0     2.0  tevragh zeina
# 2       216.0          1.0        1.0     2.0       teyarett
# 3       150.0          3.0        1.0     2.0       teyarett
# 4       180.0          3.0        2.0     2.0     toujounine
#
#                                          description  \
# 0  دار للبيع اعل شارع اكبير احذ حمام الياسمين الل...
# 1  فرصة دار ، الطابق الأرضي يحتاج ترميم بسبب المل...
# 2  سعر 9ملايين مدخله 50الف حد شاري ول عندو طلب تل...
# 3  السلام عليكم ذاك دار للبيـــــــــــــــــــــ...
# 4  السلام عليكم \nفرصة للبيـــــــــــــــــــــع...
#
#                                     caracteristiques  ... nb_pieces_total  \
# 0  Titre foncier | 1 balcon(s) | Taille rue: 15.0...  ...               5
# 1  1 balcon(s) | Taille rue: N/A | Proche de: كرف...  ...               9
# 2  Titre foncier | type de propriété: Autre | 1 b...  ...               2
# 3                                                NaN  ...               4
# 4  Titre foncier | 1 balcon(s) | Taille rue: 25.0...  ...               5
#
#   type_bien  has_garage  has_jardin  has_piscine  has_balcon has_meuble  \
# 0    maison           1           0            0           1          0
# 1    maison           1           0            0           1          0
# 2    maison           0           0            0           1          0
# 3    maison           0           0            0           0          0
# 4    maison           0           0            0           1          0
#
#    has_titre_foncier  est_neuf  age_annonce
# 0                  1         0          182
# 1                  0         0          251
# 2                  1         0           53
# 3                  0         0           95
# 4                  1         0          330
#
# [5 rows x 36 columns]
#
# Test - aperçu :
#      id                                 titre  surface_m2  nb_chambres  \
# 0   528            فرصة سمعة للبيع في كارفور        150.0          8.0
# 1  1296                          دار فدايه 19       180.0          5.0
# 2  1286  منزل جديدة ملح سكتير 2 مافات اندخلت        150.0          3.0
# 3  1021             دار كبيره فداي 11 دخلاني        180.0          4.0
# 4    64                  دار البركه اعل كدروه       180.0          4.0
#
#    nb_salons  nb_sdb    quartier  \
# 0        5.0     2.0      arafat
# 1        1.0     2.0      arafat
# 2        2.0     2.0  toujounine
# 3        2.0     2.0      arafat
# 4        2.0     2.0    teyarett
#
#                                          description  \
# 0  سمعة مؤلفة من طابق أرضي وطابق أول وأستديوه ومح...
# 1  حد دوره تلفنل اعل واتساب 26678975\nللاتصال 361...
# 2  السلام عليكم \nدغر جديدة للبيـــــــــــــــــ...
# 3  فيه اربع بيوت ومرافق وفيه بوتيك مكري فاتح اعل ...
# 4  سعر 18 مليون واحذ العنكار حد ايدور شي تلفنل 26...
#
#                                     caracteristiques      source  ...  \
# 0  1 balcon(s) | Taille rue: 30.00 | Proche de: ب...  voursa.com  ...
# 1  Titre foncier | 1 balcon(s) | Taille rue: 20.0...  voursa.com  ...
# 2  Titre foncier | 1 balcon(s) | Taille rue: 15.0...  voursa.com  ...
# 3  Titre foncier | 1 balcon(s) | Taille rue: 30.0...  voursa.com  ...
# 4  Titre foncier | 1 balcon(s) | Taille rue: 30.0...  voursa.com  ...
#
#   nb_pieces_total  type_bien  has_garage  has_jardin has_piscine  has_balcon  \
# 0              13     maison           1           0           0           1
# 1               6     maison           0           0           0           1
# 2               5     maison           0           0           0           1
# 3               6     maison           0           0           0           1
# 4               6     maison           0           0           0           1
#
#    has_meuble  has_titre_foncier  est_neuf  age_annonce
# 0           0                  0         0          339
# 1           0                  1         0          213
# 2           0                  1         1          331
# 3           0                  1         0          137
# 4           0                  1         0          127
#
# [5 rows x 33 columns]
#
# Train shape: (1153, 36)
# Test shape: (289, 33)
#
# --- Train info ---
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1153 entries, 0 to 1152
# Data columns (total 36 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    1153 non-null   int64
#  1   titre                 1153 non-null   object
#  2   prix                  1153 non-null   float64
#  3   surface_m2            1153 non-null   float64
#  4   nb_chambres           1153 non-null   float64
#  5   nb_salons             1153 non-null   float64
#  6   nb_sdb                1153 non-null   float64
#  7   quartier              1153 non-null   object
#  8   description           1153 non-null   object
#  9   caracteristiques      996 non-null    object
#  10  source                1153 non-null   object
#  11  date_publication      1153 non-null   object
#  12  quartier_encoded      1153 non-null   float64
#  13  log_prix              1153 non-null   float64
#  14  latitude              1153 non-null   float64
#  15  longitude             1153 non-null   float64
#  16  adresse_osm           1153 non-null   object
#  17  dist_centre_ville_km  1153 non-null   float64
#  18  dist_aeroport_km      1153 non-null   float64
#  19  dist_plage_km         1153 non-null   float64
#  20  nb_ecoles_1km         1153 non-null   int64
#  21  nb_mosquees_1km       1153 non-null   int64
#  22  nb_commerce_1km       1153 non-null   int64
#  23  nb_hopitaux_1km       1153 non-null   int64
#  24  nb_total_pois_1km     1153 non-null   int64
#  25  prix_m2               1153 non-null   float64
#  26  nb_pieces_total       1153 non-null   int64
#  27  type_bien             1153 non-null   object
#  28  has_garage            1153 non-null   int64
#  29  has_jardin            1153 non-null   int64
#  30  has_piscine           1153 non-null   int64
#  31  has_balcon            1153 non-null   int64
#  32  has_meuble            1153 non-null   int64
#  33  has_titre_foncier     1153 non-null   int64
#  34  est_neuf              1153 non-null   int64
#  35  age_annonce           1153 non-null   int64
# dtypes: float64(13), int64(15), object(8)
# memory usage: 324.4+ KB
#
# --- Test info ---
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 289 entries, 0 to 288
# Data columns (total 33 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    289 non-null    int64
#  1   titre                 289 non-null    object
#  2   surface_m2            289 non-null    float64
#  3   nb_chambres           289 non-null    float64
#  4   nb_salons             289 non-null    float64
#  5   nb_sdb                289 non-null    float64
#  6   quartier              289 non-null    object
#  7   description           289 non-null    object
#  8   caracteristiques      250 non-null    object
#  9   source                289 non-null    object
#  10  date_publication      289 non-null    object
#  11  quartier_encoded      289 non-null    float64
#  12  latitude              289 non-null    float64
#  13  longitude             289 non-null    float64
#  14  adresse_osm           289 non-null    object
#  15  dist_centre_ville_km  289 non-null    float64
#  16  dist_aeroport_km      289 non-null    float64
#  17  dist_plage_km         289 non-null    float64
#  18  nb_ecoles_1km         289 non-null    int64
#  19  nb_mosquees_1km       289 non-null    int64
#  20  nb_commerce_1km       289 non-null    int64
#  21  nb_hopitaux_1km       289 non-null    int64
#  22  nb_total_pois_1km     289 non-null    int64
#  23  nb_pieces_total       289 non-null    int64
#  24  type_bien             289 non-null    object
#  25  has_garage            289 non-null    int64
#  26  has_jardin            289 non-null    int64
#  27  has_piscine           289 non-null    int64
#  28  has_balcon            289 non-null    int64
#  29  has_meuble            289 non-null    int64
#  30  has_titre_foncier     289 non-null    int64
#  31  est_neuf              289 non-null    int64
#  32  age_annonce           289 non-null    int64
# dtypes: float64(10), int64(15), object(8)
# memory usage: 74.6+ KB
#
# Valeurs manquantes dans train :
# id                        0
# titre                     0
# prix                      0
# surface_m2                0
# nb_chambres               0
# nb_salons                 0
# nb_sdb                    0
# quartier                  0
# description               0
# caracteristiques        157
# source                    0
# date_publication          0
# quartier_encoded          0
# log_prix                  0
# latitude                  0
# longitude                 0
# adresse_osm               0
# dist_centre_ville_km      0
# dist_aeroport_km          0
# dist_plage_km             0
# nb_ecoles_1km             0
# nb_mosquees_1km           0
# nb_commerce_1km           0
# nb_hopitaux_1km           0
# nb_total_pois_1km         0
# prix_m2                   0
# nb_pieces_total           0
# type_bien                 0
# has_garage                0
# has_jardin                0
# has_piscine               0
# has_balcon                0
# has_meuble                0
# has_titre_foncier         0
# est_neuf                  0
# age_annonce               0
# dtype: int64
#
# Valeurs manquantes dans test :
# id                       0
# titre                    0
# surface_m2               0
# nb_chambres              0
# nb_salons                0
# nb_sdb                   0
# quartier                 0
# description              0
# caracteristiques        39
# source                   0
# date_publication         0
# quartier_encoded         0
# latitude                 0
# longitude                0
# adresse_osm              0
# dist_centre_ville_km     0
# dist_aeroport_km         0
# dist_plage_km            0
# nb_ecoles_1km            0
# nb_mosquees_1km          0
# nb_commerce_1km          0
# nb_hopitaux_1km          0
# nb_total_pois_1km        0
# nb_pieces_total          0
# type_bien                0
# has_garage               0
# has_jardin               0
# has_piscine              0
# has_balcon               0
# has_meuble               0
# has_titre_foncier        0
# est_neuf                 0
# age_annonce              0
# dtype: int64

# %% [markdown]
# Étape 2.2 : Analyse de la variable cible (prix) dans le train
# --------------------------

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Distribution du prix
plt.figure(figsize=(12,5))
plt.subplot(1,2,1)
sns.histplot(train['prix'], bins=50, kde=True)
plt.title('Distribution des prix (original)')

# Log transformation pour mieux gérer l'asymétrie
train['log_prix'] = np.log1p(train['prix'])
plt.subplot(1,2,2)
sns.histplot(train['log_prix'], bins=50, kde=True)
plt.title('Distribution de log(prix)')
plt.tight_layout()
plt.show()

# Statistiques descriptives
print(train['prix'].describe())
print(train['log_prix'].describe())
# Out:
# count    1.153000e+03
# mean     4.274850e+06
# std      4.998663e+06
# min      2.752000e+05
# 25%      1.300000e+06
# 50%      2.600000e+06
# 75%      5.800000e+06
# max      3.344000e+07
# Name: prix, dtype: float64
# count    1153.000000
# mean       14.787527
# std         0.988484
# min        12.525257
# 25%        14.077876
# 50%        14.771022
# 75%        15.573369
# max        17.325263
# Name: log_prix, dtype: float64

# %% [markdown]
# Étape 2.3 : Séparation des features (X) et de la cible (y)
# --------------------------

# %%
# Colonnes à exclure (non pertinentes ou sources de fuite de données)
colonnes_a_exclure = ['id', 'titre', 'description', 'caracteristiques', 'source', 'date_publication', 'adresse_osm', 'prix']

# Pour le train, on retire aussi 'prix' (cible) mais on garde 'log_prix' comme cible
X_train = train.drop(columns=colonnes_a_exclure)
y_train = train['log_prix']   # on utilise le log pour la régression

# Pour le test, on retire les mêmes colonnes (sauf 'prix' qui n'existe pas)
X_test = test.drop(columns=[col for col in colonnes_a_exclure if col in test.columns])

print("Features train :", X_train.columns.tolist())
print("Shape X_train:", X_train.shape)
print("Shape X_test:", X_test.shape)
# Out:
# Features train : ['surface_m2', 'nb_chambres', 'nb_salons', 'nb_sdb', 'quartier', 'quartier_encoded', 'log_prix', 'latitude', 'longitude', 'dist_centre_ville_km', 'dist_aeroport_km', 'dist_plage_km', 'nb_ecoles_1km', 'nb_mosquees_1km', 'nb_commerce_1km', 'nb_hopitaux_1km', 'nb_total_pois_1km', 'prix_m2', 'nb_pieces_total', 'type_bien', 'has_garage', 'has_jardin', 'has_piscine', 'has_balcon', 'has_meuble', 'has_titre_foncier', 'est_neuf', 'age_annonce']
# Shape X_train: (1153, 28)
# Shape X_test: (289, 26)

# %% [markdown]
# Étape 2.4 : Gestion des valeurs manquantes dans les features
# ---------------------

# %%
# --- Correction : s'assurer que les colonnes problématiques sont bien supprimées ---
colonnes_a_supprimer = ['log_prix', 'prix_m2']
for col in colonnes_a_supprimer:
    if col in X_train.columns:
        print(f"Suppression de '{col}' de X_train")
        X_train = X_train.drop(columns=[col])
    if col in X_test.columns:
        print(f"Suppression de '{col}' de X_test")
        X_test = X_test.drop(columns=[col])

# Maintenant, aligner à nouveau les colonnes (au cas où)
train_cols = X_train.columns.tolist()
test_cols = X_test.columns.tolist()

# Ajouter les colonnes manquantes dans test avec des 0
missing_in_test = set(train_cols) - set(test_cols)
for col in missing_in_test:
    X_test[col] = 0

# Supprimer les colonnes en trop dans test
extra_in_test = set(test_cols) - set(train_cols)
if extra_in_test:
    X_test = X_test.drop(columns=extra_in_test)

# Réordonner les colonnes de test selon l'ordre de train
X_test = X_test[train_cols]

# --- Imputation ---
from sklearn.impute import SimpleImputer

# Identifier les colonnes numériques (toutes maintenant)
numerical_cols = X_train.select_dtypes(include=np.number).columns.tolist()
print("Colonnes numériques après nettoyage :", numerical_cols)

# Créer et appliquer l'imputeur
imputer = SimpleImputer(strategy='median')
X_train[numerical_cols] = imputer.fit_transform(X_train[numerical_cols])
X_test[numerical_cols] = imputer.transform(X_test[numerical_cols])

# Vérification
print("NaN dans train après imputation :", X_train.isnull().sum().sum())
print("NaN dans test après imputation :", X_test.isnull().sum().sum())
# Out:
# Suppression de 'log_prix' de X_train
# Suppression de 'prix_m2' de X_train
# Colonnes numériques après nettoyage : ['surface_m2', 'nb_chambres', 'nb_salons', 'nb_sdb', 'quartier_encoded', 'latitude', 'longitude', 'dist_centre_ville_km', 'dist_aeroport_km', 'dist_plage_km', 'nb_ecoles_1km', 'nb_mosquees_1km', 'nb_commerce_1km', 'nb_hopitaux_1km', 'nb_total_pois_1km', 'nb_pieces_total', 'has_garage', 'has_jardin', 'has_piscine', 'has_balcon', 'has_meuble', 'has_titre_foncier', 'est_neuf', 'age_annonce']
# NaN dans train après imputation : 0
# NaN dans test après imputation : 0

# %% [markdown]
# Étape 2.5 : (Optionnel) Standardisation / Normalisation
# ---------------------

# %%
from sklearn.preprocessing import StandardScaler
def prepare_features(X_train, X_test, colonnes_a_exclure):
    # Suppression
    for col in colonnes_a_exclure:
        if col in X_train.columns:
            X_train = X_train.drop(columns=[col])
        if col in X_test.columns:
            X_test = X_test.drop(columns=[col])
    
    # Alignement
    train_cols = X_train.columns.tolist()
    for col in train_cols:
        if col not in X_test.columns:
            X_test[col] = 0
    X_test = X_test[train_cols]
    
    # Imputation
    imputer = SimpleImputer(strategy='median')
    X_train = pd.DataFrame(imputer.fit_transform(X_train), columns=X_train.columns)
    X_test = pd.DataFrame(imputer.transform(X_test), columns=X_test.columns)
    
    # Standardisation
    scaler = StandardScaler()
    X_train = pd.DataFrame(scaler.fit_transform(X_train), columns=X_train.columns)
    X_test = pd.DataFrame(scaler.transform(X_test), columns=X_test.columns)
    
    return X_train, X_test, imputer, scaler

# Utilisation
colonnes_a_exclure = ['id', 'titre', 'description', 'caracteristiques', 'source', 'date_publication',
                      'adresse_osm', 'prix_m2', 'log_prix', 'quartier', 'type_bien']
X_train, X_test, imputer, scaler = prepare_features(X_train, X_test, colonnes_a_exclure)

# %% [markdown]
# Étape 2.6 : Vérification finale
# ----------

# %%
print("Train final shape:", X_train.shape)
print("Test final shape:", X_test.shape)
print("y_train shape:", y_train.shape)
# Out:
# Train final shape: (1153, 24)
# Test final shape: (289, 24)
# y_train shape: (1153,)

# %% [markdown]
# Étape 3.1 : Import des modèles et métriques
# -------------------------------

# %%
from sklearn.linear_model import LinearRegression, Ridge, Lasso
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from sklearn.model_selection import cross_validate, KFold
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score, mean_squared_log_error
import xgboost as xgb
import pandas as pd
import numpy as np
import joblib
import matplotlib.pyplot as plt

# %% [markdown]
# Étape 3.2 : Définition des modèles à tester
# ------------------------------------

# %%
models = {
    'Linear Regression': LinearRegression(),
    'Ridge': Ridge(alpha=1.0),
    'Lasso': Lasso(alpha=0.001, max_iter=10000),
    'Random Forest': RandomForestRegressor(n_estimators=100, random_state=42, n_jobs=-1),
    'Gradient Boosting': GradientBoostingRegressor(n_estimators=100, random_state=42),
    'XGBoost': xgb.XGBRegressor(n_estimators=100, learning_rate=0.1, random_state=42, n_jobs=-1)
}

# %% [markdown]
# Étape 3.3 : Configuration de la validation croisée
# ------------------

# %%
kfold = KFold(n_splits=5, shuffle=True, random_state=42)


scoring = {
    'rmse': 'neg_root_mean_squared_error',
    'mae': 'neg_mean_absolute_error',
    'r2': 'r2'
}

# %% [markdown]
# Étape 3.4 : Boucle d'évaluation de chaque modèle
# --------------------------------------

# %%
results = []

for name, model in models.items():
    print(f"🔍 Évaluation du modèle : {name}...")
    
    cv_results = cross_validate(model, X_train, y_train, cv=kfold, scoring=scoring, return_train_score=True)
    
    # Les scores sont négatifs pour rmse et mae, on prend la valeur absolue
    rmse_mean = -cv_results['test_rmse'].mean()
    rmse_std = cv_results['test_rmse'].std()
    mae_mean = -cv_results['test_mae'].mean()
    r2_mean = cv_results['test_r2'].mean()
    
    results.append({
        'Modèle': name,
        'RMSE (moy)': rmse_mean,
        'RMSE (std)': rmse_std,
        'MAE (moy)': mae_mean,
        'R² (moy)': r2_mean
    })
    
    print(f"   ✅ RMSE: {rmse_mean:.4f} (±{rmse_std:.4f}), MAE: {mae_mean:.4f}, R²: {r2_mean:.4f}\n")

# Convertir en DataFrame pour affichage
results_df = pd.DataFrame(results)
print("\n📊 Résultats de la validation croisée :")
print(results_df.to_string(index=False))
# Out:
# 🔍 Évaluation du modèle : Linear Regression...
#    ✅ RMSE: 0.6595 (±0.0688), MAE: 0.4606, R²: 0.5531
#
# 🔍 Évaluation du modèle : Ridge...
#    ✅ RMSE: 0.6592 (±0.0693), MAE: 0.4604, R²: 0.5535
#
# 🔍 Évaluation du modèle : Lasso...
#    ✅ RMSE: 0.6592 (±0.0695), MAE: 0.4605, R²: 0.5535
#
# 🔍 Évaluation du modèle : Random Forest...
#    ✅ RMSE: 0.6770 (±0.0655), MAE: 0.4735, R²: 0.5290
#
# 🔍 Évaluation du modèle : Gradient Boosting...
#    ✅ RMSE: 0.6497 (±0.0736), MAE: 0.4478, R²: 0.5656
#
# 🔍 Évaluation du modèle : XGBoost...
#    ✅ RMSE: 0.6747 (±0.0739), MAE: 0.4672, R²: 0.5314
#
#
# 📊 Résultats de la validation croisée :
#            Modèle  RMSE (moy)  RMSE (std)  MAE (moy)  R² (moy)
# Linear Regression    0.659531    0.068835   0.460591  0.553107
#             Ridge    0.659209    0.069321   0.460398  0.553479
#             Lasso    0.659203    0.069513   0.460484  0.553454
#     Random Forest    0.677035    0.065514   0.473473  0.529015
# Gradient Boosting    0.649742    0.073633   0.447788  0.565614
#           XGBoost    0.674733    0.073924   0.467205  0.531419

# %% [markdown]
# Étape 3.5 : Sélection du meilleur modèle
# --------------------------------

# %%
best_row = results_df.loc[results_df['RMSE (moy)'].idxmin()]
best_model_name = best_row['Modèle']
best_model = models[best_model_name]

print(f"\n🏆 Meilleur modèle : {best_model_name}")
print(f"   RMSE moyen : {best_row['RMSE (moy)']:.4f}")
print(f"   R² moyen : {best_row['R² (moy)']:.4f}")
# Out:
# 🏆 Meilleur modèle : Gradient Boosting
#    RMSE moyen : 0.6497
#    R² moyen : 0.5656

# %% [markdown]
# Étape 3.6 : Réentraînement du meilleur modèle sur toutes les données d'entraînement
# ------------------------

# %%
print(f"\n🔄 Entraînement final du meilleur modèle sur tout le train...")
best_model.fit(X_train, y_train)
# Out:
# 🔄 Entraînement final du meilleur modèle sur tout le train...
# GradientBoostingRegressor(random_state=42)

# %% [markdown]
# Étape 3.7 : Prédictions sur le jeu de test
# -------------------------------

# %%
y_pred_log = best_model.predict(X_test)
y_pred = np.expm1(y_pred_log)  # car on avait utilisé log1p (log(1+prix)) → expm1 pour revenir

# %% [markdown]
# Étape 3.8 : Création du fichier de soumission pour Kaggle
# ---------------------

# %%
# Charger le test original pour récupérer les id
test = pd.read_csv('../data/test.csv')
submission = pd.DataFrame({
    'id': test['id'],
    'prix': y_pred
})

# Sauvegarder au format CSV (sans index)
submission.to_csv('submission7.csv', index=False)
print("✅ Fichier 'submission7.csv' créé avec succès !")
# Out:
# ✅ Fichier 'submission7.csv' créé avec succès !

# %% [markdown]
# Étape 3.9 : Sauvegarde du modèle et des objets de prétraitement (optionnel)
# ------------------------------------

# %%
from sklearn.preprocessing import OneHotEncoder

# Supposons que 'type_bien' est la colonne catégorielle originale
encoder = OneHotEncoder(sparse_output=False, handle_unknown='ignore')
encoder.fit(train[['type_bien']])  # ou X_train_original contenant 'type_bien'

# Maintenant vous pouvez le sauvegarder
joblib.dump(encoder, 'encoder.pkl')

# Sauvegarde du modèle
joblib.dump(best_model, 'best_model.pkl')

# Sauvegarde de l'imputer et du scaler si vous les avez utilisés
joblib.dump(imputer, 'imputer.pkl')
joblib.dump(scaler, 'scaler.pkl')
joblib.dump(encoder, 'encoder.pkl')  # pour l'encodage de type_bien

print("✅ Modèle et préprocesseurs sauvegardés.")
# Out:
# ✅ Modèle et préprocesseurs sauvegardés.

# %%
from sklearn.preprocessing import OneHotEncoder
import joblib

# Supposons que 'type_bien' est la colonne catégorielle originale
encoder = OneHotEncoder(sparse_output=False, handle_unknown='ignore')
encoder.fit(train[['type_bien']])  # ou X_train_original contenant 'type_bien'

# Sauvegarde de tous les composants au format joblib
joblib.dump(best_model, 'best_model.joblib')
joblib.dump(imputer, 'imputer.joblib')
joblib.dump(scaler, 'scaler.joblib')
joblib.dump(encoder, 'encoder.joblib')

print("✅ Modèle et préprocesseurs sauvegardés au format joblib.")
# Out:
# ✅ Modèle et préprocesseurs sauvegardés au format joblib.

# %% [markdown]
# Étape 3.10 : (Bonus) Calcul du RMSLE sur l'entraînement pour vérification
# ------------------

# %%
# Prédire sur l'entraînement
y_train_pred_log = best_model.predict(X_train)
y_train_pred = np.expm1(y_train_pred_log)
y_train_true = np.expm1(y_train)  # car y_train est log_prix

rmsle = np.sqrt(mean_squared_log_error(y_train_true, y_train_pred))
print(f"RMSLE sur l'entraînement (après réentraînement) : {rmsle:.4f}")
# Out:
# RMSLE sur l'entraînement (après réentraînement) : 0.5344
